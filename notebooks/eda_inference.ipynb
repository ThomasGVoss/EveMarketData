# %%
# %pip install polars --quiet
# %pip install matplotlib --quiet
# %pip install seaborn --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests
import datetime
from pprint import pprint
import polars as pl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = (
    pl.scan_csv(
        source="s3://sagemaker-dev-142571790518/abalone-inference-dev/abalone-inference-dev--2025-07-07--18-08-30--176def82/modelArtifacts/transform/data.csv.out",
        has_header=False
    )
    .collect()
)

# %%
df
# Out:
# shape: (17_302, 12)
# ┌──────────┬──────────┬──────────┬──────────┬───┬──────────┬───────────┬───────────┬───────────────┐
# │ column_1 ┆ column_2 ┆ column_3 ┆ column_4 ┆ … ┆ column_9 ┆ column_10 ┆ column_11 ┆ column_12     │
# │ ---      ┆ ---      ┆ ---      ┆ ---      ┆   ┆ ---      ┆ ---       ┆ ---       ┆ ---           │
# │ f64      ┆ f64      ┆ f64      ┆ f64      ┆   ┆ f64      ┆ f64       ┆ f64       ┆ f64           │
# ╞══════════╪══════════╪══════════╪══════════╪═══╪══════════╪═══════════╪═══════════╪═══════════════╡
# │ 1.59e6   ┆ 3.8e6    ┆ 1.595e6  ┆ 3.8e6    ┆ … ┆ 20.0     ┆ 16.0      ┆ 22.0      ┆ 7490465.5     │
# │ 295000.0 ┆ 495000.0 ┆ 299000.0 ┆ 400000.0 ┆ … ┆ 18.0     ┆ 0.0       ┆ 0.0       ┆ -5.228939e6   │
# │ 7777.0   ┆ 370500.0 ┆ 7777.0   ┆ 370500.0 ┆ … ┆ 23.0     ┆ 0.0       ┆ 0.0       ┆ -5.315335e6   │
# │ 15980.0  ┆ 49000.0  ┆ 24840.0  ┆ 33990.0  ┆ … ┆ 15.0     ┆ 0.0       ┆ 0.0       ┆ -627945.875   │
# │ 4704.0   ┆ 10000.0  ┆ 4692.0   ┆ 10000.0  ┆ … ┆ 0.0      ┆ 0.0       ┆ 0.0       ┆ -1.5826e6     │
# │ …        ┆ …        ┆ …        ┆ …        ┆ … ┆ …        ┆ …         ┆ …         ┆ …             │
# │ 777.0    ┆ 7600.0   ┆ 777.0    ┆ 3377.0   ┆ … ┆ 17.0     ┆ 0.0       ┆ 0.0       ┆ -3.240316e6   │
# │ 63.0     ┆ 90.0     ┆ 63.0     ┆ 90.0     ┆ … ┆ 21.0     ┆ 0.0       ┆ 0.0       ┆ 1.49296e6     │
# │ 50000.0  ┆ 149900.0 ┆ 50000.0  ┆ 149900.0 ┆ … ┆ 20.0     ┆ 15.0      ┆ 19.0      ┆ 554775.8125   │
# │ 6.17     ┆ 27.85    ┆ 6.17     ┆ 28.99    ┆ … ┆ 0.0      ┆ 0.0       ┆ 0.0       ┆ -3.029099e6   │
# │ 600000.0 ┆ 600000.0 ┆ 600000.0 ┆ 600000.0 ┆ … ┆ 18.0     ┆ 20.0      ┆ 18.0      ┆ -214950.67187 │
# │          ┆          ┆          ┆          ┆   ┆          ┆           ┆           ┆ 5             │
# └──────────┴──────────┴──────────┴──────────┴───┴──────────┴───────────┴───────────┴───────────────┘
